# %%
# ===== 모델 및 컬럼 구조 불러오기 =====
import joblib

gam_package = joblib.load("../models/gam_model.pkl")
gam = gam_package["model"]
X_columns = gam_package["columns"]

gam.summary()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 # ===== 모델 및 컬럼 구조 불러오기 =====
#       2 import joblib
# ----> 4 gam_package = joblib.load("./models/gam_model.pkl")
#       5 gam = gam_package["model"]
#       6 X_columns = gam_package["columns"]
#
# File c:\Users\human\anaconda3\envs\py311\Lib\site-packages\joblib\numpy_pickle.py:735, in load(filename, mmap_mode, ensure_native_byte_order)
#     733         obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734 else:
# --> 735     with open(filename, "rb") as f:
#     736         with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737             fobj,
#     738             validated_mmap_mode,
#     739         ):
#     740             if isinstance(fobj, str):
#     741                 # if the returned file object is a string, this means we
# ...
