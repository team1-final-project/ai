# %%
# ===== 모델 및 컬럼 구조 불러오기 =====
import joblib

gam_package = joblib.load("../models/gam_model.pkl")
gam = gam_package["model"]
X_columns = gam_package["columns"]

gam.summary()
# Out:
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     27.3444
# Link Function:                     IdentityLink Log Likelihood:                               -173177.3318
# Number of Samples:                        26195 AIC:                                           346411.3523
#                                                 AICc:                                          346411.4159
#                                                 GCV:                                            32442.1683
#                                                 Scale:                                            179.9478
#                                                 Pseudo R-Squared:                                   0.7789
# ...
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ...
